# %% [markdown]
# ## Greedy

# %% [markdown]
# ### Intuition
# - If there are any `nums[i] > nums[i + i]`, break down `nums[i]` into smaller numbers
# - Traverse in reverse order, ensuring that suffix array remains sorted
# - Strategy for breaking numbers apart
#     - If `nums[i]` is multiple of `nums[i + 1]`, break `nums[i]` into multiple `nums[i + 1]`
#     - Otherwise, break `nums[i]` into `(nums[i] // nums[i + 1] + 1)` sorted elements, largest being `nums[i + 1] ` and smallest being `nums[i + 1] - 1`
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Algorithm
# 1. `answer = 0` and `n = len(nums)`
# 2. Iterate over `nums` backward from `nums[n - 2]`
#     - If `nums[i] <= nums[i + 1]`, move onto `nums[i - 1]`
#     - If `nums[i]` is multiple of `nums[i + 1]`, break `nums[i]` into `num_elements = nums[i] / nums[i + 1]`
#     - Otherwise, break `nums[i]` into `num_elements = nums[i] / nums[i + 1] + 1` elements, requiring `num_elements - 1` operations. `answer += num_elements - 1`
#     - Largest possible `nums[i]` is `nums[i] / num_elements`, udpate `nums[i]` as `nums[i] / num_elements`

# %% [markdown]
# ### Implementation

# %%
def minimum_replacement(nums):
    answer = 0
    n = len(nums)

    for i in range(n - 2, -1, -1):
        if nums[i] <= nums[i + 1]:
            continue
    
        num_elements = (nums[i] + nums[i + 1] - 1) // nums[i + 1]
        answer += num_elements - 1
        nums[i] //= num_elements
    
    return answer
